# %%
# %matplotlib inline

import numpy as np # NUMPY
import pandas as pd # PANDAS
import scipy
import sklearn
import random as rd
from IPython.display import display
import os 
from pathlib import Path
import shutil

# %% [markdown]
# ### IF WE HAVE THE CK+ DATABASE, WE CAN DO THIS CODE IN THE NEXTS CELLS TO CREATE A MINI DATABASE TO START WITH THE FEATURES

# %%
 len(os.listdir('../../ck+/Landmarks' ))
# Out:
# 123

# %% [markdown]
# ##Elegimos la cantidad de sujetos para la extraccion (=11) de ck al azar. Luego eligiremos una con interseccion 0 para la evaluacio (y una parte mas chica con interseccion 0 con las otras 2 papra validacion)

# %%
Emotion_subjects = os.listdir('../../ck+/Emotion_labels/Emotion' )
len(Emotion_subjects)
images_subjects = os.listdir('../../ck+/extended-cohn-kanade-images/cohn-kanade-images' )
len(images_subjects)
facts_subjects =  os.listdir('../../ck+/FACS_labels/FACS' )
len(facts_subjects)
landmarks_subjects =  os.listdir('../../ck+/Landmarks' )
len(landmarks_subjects)
# Out:
# 123

# %%
#dir is not keyword
#def makemydir(whatever):
#  try:
#    os.makedirs(whatever)
#  except OSError:
#    pass
  # let exception propagate if we just can't
##  # cd into the specified directory
#  os.chdir(whatever)
    
#makemydir()

# %%
def do_assigned_dir(orsrc, ordst, subjects):
    for number in subjects:
        src = orsrc + number
        dst = ordst + number
        destination = shutil.copytree(src, dst)
        print(destination)
    return 0

# %%
do_assigned_dir('../../ck+/extended-cohn-kanade-images/cohn-kanade-images/', '../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/', images_subjects )
do_assigned_dir('../../ck+/Emotion_labels/Emotion/', '../ck+copyAgain/Emotion_labels/Emotion/', Emotion_subjects )
do_assigned_dir('../../ck+/FACS_labels/FACS/', '../ck+copyAgain/FACS_labels/FACS/', facts_subjects )
do_assigned_dir('../../ck+/Landmarks/', '../ck+copyAgain/Landmarks/', landmarks_subjects )
# Out:
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S125
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S133
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S078
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S117
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S029
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S035
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S109
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S079
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S076
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S099
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S051
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S156
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S148
# ../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/S506
# ...

# %% [markdown]
# #### Aqui sacamos las carpetas que no tienen emocion definida o es contempt, que no usamos

# %%
deletefolders = []
for number in Emotion_subjects:
  
    src ='../ck+copyAgain/Emotion_labels/Emotion/'  + number
    emotion_folders = np.sort(os.listdir(src))
    for number_emo in emotion_folders:
        emotion = src  +'/'+ number_emo             
        if not os.listdir(emotion):
            deletefolders.append([number, number_emo])
        else:
            filelabel = os.listdir(emotion)[0]
            with open(emotion+ '/'+filelabel) as f:
                line = float(f.readline())
            if (line ==2.0):
                deletefolders.append([number,number_emo])
                # 2 == contempt emotion

# %%
deletefolders
# Out:
# [['S125', '002'],
#  ['S125', '003'],
#  ['S125', '004'],
#  ['S133', '001'],
#  ['S133', '002'],
#  ['S133', '004'],
#  ['S078', '002'],
#  ['S078', '003'],
#  ['S078', '005'],
#  ['S078', '006'],
#  ['S117', '002'],
#  ['S117', '004'],
#  ['S117', '005'],
#  ['S117', '007'],
#  ['S035', '002'],
#  ['S035', '003'],
#  ['S035', '004'],
#  ['S109', '001'],
#  ['S109', '002'],
#  ['S109', '004'],
#  ['S079', '003'],
#  ['S076', '002'],
#  ['S076', '003'],
#  ['S076', '004'],
#  ['S099', '002'],
#  ['S099', '003'],
#  ['S051', '001'],
#  ['S156', '002'],
#  ['S148', '002'],
#  ['S506', '002'],
#  ['S045', '001'],
#  ['S045', '002'],
#  ['S045', '003'],
#  ['S077', '002'],
#  ['S077', '003'],
#  ['S077', '004'],
#  ['S077', '005'],
#  ['S077', '007'],
#  ['S502', '002'],
#  ['S052', '002'],
#  ['S052', '003'],
#  ['S014', '004'],
#  ['S095', '002'],
#  ['S095', '003'],
#  ['S095', '004'],
#  ['S095', '005'],
#  ['S104', '001'],
#  ['S104', '002'],
#  ['S104', '003'],
#  ['S083', '001'],
# ...

# %%
for folder in deletefolders:
    image = '../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/'+ folder[0]+'/' + folder[1]
    facs =  '../ck+copyAgain/FACS_labels/FACS/'+ folder[0]+'/' + folder[1]
    emotion = '../ck+copyAgain/Emotion_labels/Emotion/' + folder[0]+ '/' + folder[1]
    landmark = '../ck+copyAgain/Landmarks/' + folder[0]+ '/' + folder[1]
    shutil.rmtree(image)
    shutil.rmtree(facs)
    shutil.rmtree(emotion)
    shutil.rmtree(landmark)

# %%
len(os.listdir('../ck+copyAgain/Landmarks' )) #cant de sujetos. No son la cantidad total de series, que es lo que importa.
# Out:
# 123

# %%
from glob import glob

len(glob("../ck+copyAgain/Landmarks/*/", recursive = True))
# cant de sujetos de prueba = 123
len(glob("../ck+copyAgain/Landmarks/*/*", recursive = True))
# cant de secuencias de imagenes = 320
len(glob("../ck+copyAgain/Landmarks/*/*/*", recursive = True))
# cant de frames de secuencias = 5849
# Out:
# 5849

# %%
len(glob("../ck+copynew/Landmarks/*/*", recursive = True))

# %%
#Nos interesa tener el 70% de las secuencias, por lo que vemos el numero que
#hace eso cierto, y sacamos sujetos hasta tener ese numero
def percentage(percent, whole):
  return int((percent * whole) / 100.0)

percentage(70,320)
# Out:
# 224

# %%
def choose_random_subjects(main_dir, local_dir, amount):
    subjects = os.listdir(main_dir + local_dir )
    random_subjects = np.random.choice(subjects, amount,replace=False )
    
    return random_subjects
    
subject_number =choose_random_subjects('../ck+copyAgain/','extended-cohn-kanade-images/cohn-kanade-images', percentage(70, len(Emotion_subjects)))

len(subject_number)
# Out:
# 86

# %%
subject_number
# Out:
# array(['S119', 'S104', 'S065', 'S011', 'S501', 'S131', 'S108', 'S128',
#        'S138', 'S127', 'S014', 'S137', 'S134', 'S505', 'S069', 'S122',
#        'S133', 'S054', 'S091', 'S158', 'S116', 'S895', 'S077', 'S109',
#        'S005', 'S056', 'S046', 'S055', 'S075', 'S082', 'S114', 'S092',
#        'S100', 'S052', 'S147', 'S090', 'S072', 'S148', 'S115', 'S086',
#        'S073', 'S160', 'S060', 'S117', 'S084', 'S045', 'S089', 'S504',
#        'S503', 'S067', 'S096', 'S155', 'S010', 'S129', 'S106', 'S035',
#        'S112', 'S080', 'S157', 'S107', 'S053', 'S064', 'S087', 'S085',
#        'S051', 'S121', 'S068', 'S078', 'S135', 'S028', 'S097', 'S066',
#        'S118', 'S105', 'S103', 'S074', 'S098', 'S125', 'S101', 'S063',
#        'S059', 'S062', 'S095', 'S042', 'S502', 'S126'], dtype='<U4')

# %%
def cant_of_series_of_subjects(sublist):
    cant = 0
    for sub in subject_number:
        path = '../ck+copynew/extended-cohn-kanade-images/cohn-kanade-images/' + sub + '/'
        subject_series_q = os.listdir(path)        
        cant = cant + len(subject_series_q)
    return cant

cant_of_series_of_subjects(subject_number)
# Out:
# 231

# %%
# tenemos el 74% de series para training (236/320), sacadas de usar el 70% de sujetos de la 
#database (86/123)

# %%
len(os.listdir('../ck+copynewT/extended-cohn-kanade-images/cohn-kanade-images/'))
# Out:
# 86

# %%
subject_number = np.sort(os.listdir('../ck+copynewT/extended-cohn-kanade-images/cohn-kanade-images/'))

# %%
subject_number
# Out:
# array(['S010', 'S011', 'S014', 'S022', 'S026', 'S029', 'S032', 'S034',
#        'S035', 'S037', 'S044', 'S050', 'S051', 'S052', 'S053', 'S054',
#        'S055', 'S057', 'S058', 'S059', 'S060', 'S061', 'S063', 'S064',
#        'S065', 'S066', 'S067', 'S068', 'S069', 'S072', 'S074', 'S075',
#        'S077', 'S078', 'S080', 'S081', 'S082', 'S087', 'S088', 'S091',
#        'S092', 'S093', 'S095', 'S096', 'S097', 'S099', 'S100', 'S101',
#        'S102', 'S103', 'S104', 'S106', 'S108', 'S109', 'S110', 'S112',
#        'S113', 'S115', 'S117', 'S118', 'S119', 'S120', 'S121', 'S122',
#        'S124', 'S125', 'S126', 'S128', 'S129', 'S131', 'S133', 'S136',
#        'S137', 'S139', 'S147', 'S148', 'S149', 'S151', 'S154', 'S155',
#        'S157', 'S158', 'S503', 'S505', 'S506', 'S999'], dtype='<U4')

# %%
def moveto_assigned_dir(orsrc, ordst, subjects):
    for number in subjects:
        src = orsrc + number
        dst = ordst + number
        destination = shutil.move(src, dst)
        print(destination)
    return 0

# %%
moveto_assigned_dir('../ck+copyAgain/extended-cohn-kanade-images/cohn-kanade-images/', '../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/', subject_number )
moveto_assigned_dir('../ck+copyAgain/Emotion_labels/Emotion/', '../ck+copyAgainT/Emotion_labels/Emotion/' , subject_number )
moveto_assigned_dir('../ck+copyAgain/FACS_labels/FACS/', '../ck+copyAgainT/FACS_labels/FACS/' , subject_number )
moveto_assigned_dir('../ck+copyAgain/Landmarks/', '../ck+copyAgainT/Landmarks/', subject_number )
# Out:
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S010
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S011
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S014
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S022
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S026
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S029
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S032
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S034
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S035
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S037
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S044
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S050
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S051
# ../ck+copyAgainT/extended-cohn-kanade-images/cohn-kanade-images/S052
# ...

# %%
from glob import glob 
len(glob("../ck+copyAgainT/Landmarks/*/*/", recursive = True))
longitud_series = []
for i in np.sort(glob("../ck+copyAgainT/Landmarks/*/*/", recursive = True)):
    subject = i.split('/')[3]
    serie = i.split('/')[4]
    actual = subject + '/'+ serie
    path = '../ck+copyAgainT/Emotion_labels/Emotion/' +actual
    filelabel = (os.listdir(path))[0]
    longitud = int(len(os.listdir(i)))
    with open(path+ '/'+filelabel) as f:        
        line = float(f.readline())         
    if line == 4 or line == 6:
        longitud_series.append(int(longitud/4))
    else:
        longitud_series.append(int(longitud/2))
        
        

    
    #if 
    #longitud_series.append(os.listdir(i))

# %%
longitud_series
# Out:
# [7,
#  9,
#  7,
#  8,
#  5,
#  3,
#  10,
#  10,
#  6,
#  14,
#  4,
#  15,
#  8,
#  15,
#  16,
#  8,
#  7,
#  4,
#  7,
#  6,
#  9,
#  11,
#  8,
#  3,
#  8,
#  8,
#  14,
#  13,
#  5,
#  7,
#  9,
#  9,
#  10,
#  11,
#  10,
#  12,
#  7,
#  9,
#  4,
#  9,
#  10,
#  11,
#  9,
#  9,
#  7,
#  16,
#  6,
#  11,
#  12,
#  3,
#  3,
#  12,
#  6,
#  4,
#  14,
#  22,
#  2,
#  9,
#  7,
#  16,
#  10,
#  5,
#  9,
#  9,
#  4,
#  13,
#  9,
#  10,
#  6,
#  7,
#  11,
#  6,
#  11,
#  6,
#  12,
#  3,
#  5,
#  11,
#  14,
#  4,
#  11,
#  6,
#  2,
#  5,
#  7,
#  11,
#  11,
#  5,
#  7,
#  7,
#  2,
#  10,
#  7,
#  5,
#  8,
#  9,
#  11,
#  5,
#  8,
#  9,
#  21,
#  7,
#  6,
#  12,
#  6,
#  14,
#  7,
#  16,
#  13,
#  6,
#  9,
#  3,
#  4,
#  9,
#  6,
#  5,
#  7,
#  8,
#  5,
#  5,
#  6,
#  6,
#  8,
#  8,
#  10,
#  3,
#  10,
#  8,
#  7,
#  12,
#  5,
#  8,
#  8,
#  6,
#  10,
#  3,
#  3,
#  6,
#  5,
#  10,
#  15,
#  9,
#  7,
#  7,
#  6,
#  7,
#  7,
#  11,
#  8,
#  9,
#  9,
#  4,
#  7,
#  4,
#  4,
#  5,
#  5,
#  10,
# ...

# %%
#len(os.listdir('../ck+copynew/extended-cohn-kanade-images/cohn-kanade-images/'))
# cant de sujetos de test 37
len(glob("../ck+copynew/Landmarks/*/*/", recursive = True))
#cant de series de test 95
len(glob("../ck+copynew/Landmarks/*/*/*", recursive = True))
#cant de frames de test = 1727
# Out:
# 1727

# %%
#len(os.listdir('../ck+copynewT/extended-cohn-kanade-images/cohn-kanade-images/'))
#cant de sujetos de training 86
len(glob("../ck+copynewT/Landmarks/*/*/", recursive = True))
#cant de series de training 225
len(glob("../ck+copynewT/Landmarks/*/*/*", recursive = True))
#cant de frames de training =4122
# Out:
# 450

# %%
#Tenemos 225 series de training
#225*2+86
#nos quedamos con las ultimas 2 frames de cada secuencia y 1 cara neutral por sujeto
for i in 
#le quitamos 
#225+86
# Out:
# 311

# %%
series_landmark = np.sort(glob("../ck+copynewT/Landmarks/*/*/", recursive = True))

for serie in series_landmark:
    path = serie +'/*'
    frames = np.sort(glob(path))
    for i in range (1, (len(frames)-1)):
        os.remove(frames[i])

# %%
series_images = np.sort(glob("../ck+copynewT/extended-cohn-kanade-images/cohn-kanade-images/*/*/", recursive = True))

for serie in series_images:
    path = serie +'/*'
    frames = np.sort(glob(path))
    for i in range (1, (len(frames)-1)):
        os.remove(frames[i])

# %%
np.sqrt(311)*5
# Out:
# 88.17596044274198

# %%
subjects_landmarks = '../ck+copy/Landmarks/'
sorted_subjects =   np.sort(os.listdir('../ck+copy/Landmarks/'))  
one_subject_landmarks = '../ck+copy/Landmarks/' + 'S064/'
sorted_list = np.sort(os.listdir('../ck+copy/Landmarks/' + 'S064/')) #creo que este sort se puede quitar


    
distances_per_subject = []
for emotion in sorted_list:
    matrix_landmark_per_frame = []
    subject_landmark_emotion = one_subject_landmarks + str(emotion)    
    for i in range(0, len(os.listdir(subject_landmark_emotion))):
        data = pd.read_csv('../ck+copy/Landmarks/' + 'S064/' + str(emotion)+'/'+'S064_'+str(emotion)+'_'+ str(i+1).zfill(8)+'_landmarks.txt',  header=None)
        data.columns =['landmarks']
        quantity_of_landmarks = data.size #68
        data = data['landmarks'].str.split('   ', expand=True)
        data.columns =['landmarks', 'landmarkX', 'landmarkY']
        data =data.drop(columns=['landmarks'])
        landmarkXY=data['landmarkX'].append(data['landmarkY'], ignore_index=True)
        matrix_landmark_per_frame.append(landmarkXY_array)
    frame0 = matrix_landmark_per_frame[0]
    distance_landmark_per_frame = matrix_landmark_per_frame
    for i in range(0, len(distance_landmark_per_frame)):
        distance_landmark_per_frame[i] = distance_landmark_per_frame[i] - frame0
    distances_per_subject.append(distance_landmark_per_frame)

# %%
subject_landmarks = glob

# %%
len(glob("../ck+copynewT/extended-cohn-kanade-images/cohn-kanade-images/*/*/", recursive = True))
# Out:
# 225

# %%
for i in

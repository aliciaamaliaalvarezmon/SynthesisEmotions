# %%
# %matplotlib inline

import numpy as np # NUMPY
import pandas as pd # PANDAS
import matplotlib.pyplot as plt # MATPLOTLIB
import seaborn as sns # SEABORN
import scipy
import sklearn
from sklearn.decomposition import PCA
import cv2
import os 
from skimage import filters
from scipy import ndimage
import math

# %%
import glob
from pathlib import Path

# %%
# %run auxfunctions.ipynb

# %%
# Vamos a hacerlo para 1 secuencia. Luego veremos como hacerlo para varias
#secuencias.
#Objetivo. Tener los b_vectors, target_emotions para pasar al colab

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#Shape_PCA

my_data_forPCA = pd.read_csv('my_training_data_aligned_diff_newT.csv',header = None)
fear_data_forPCA = pd.read_csv('my_training_data_aligned_diff_newT_fear.csv',header = None)
sadness_data_forPCA = pd.read_csv('my_training_data_aligned_diff_newT_sadness.csv',header = None)
old_and_sadfear_PCA = pd.concat([my_data_forPCA, fear_data_forPCA, sadness_data_forPCA ])
#my_data_forPCA = pd.read_csv('my_training_data_aligned_diff.csv',header = None)

std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(old_and_sadfear_PCA)
scaled_landDiff.shape

pca_shape = PCA(n_components=29)
b_shape = pca_shape.fit_transform(scaled_landDiff)
b_shape.shape
# Out:
# (490, 29)

# %%
import glob
test_images_labels = {}

path_to_test_emotion ='../ck+copynew/Emotion_labels/Emotion/'

series_test = glob.glob(path_to_test_emotion + '*/*/*', recursive = True)
series_select = series_test
#series_select = np.random.choice(series_test, 20, replace=False )

# %%
len(series_test)#hay algunas que no tienen tag de emocion
# Out:
# 94

# %%
series_select = np.sort(series_select)

# %%
len(series_select)
# Out:
# 94

# %%
series_emotion = []
path = 'ck+copynewTfile/transformed_test_images_total/'
test_series = glob.glob(path + '*/*/', recursive = True)
test_series = np.sort(test_series)
path_to_test_emotion ='../ck+copynew/Emotion_labels/Emotion/'

for i in np.sort(test_series):   
    actual_subject = str(i).split('/')[2]
    actual_subfolder = str(i).split('/')[3]
    actual_serie = actual_subject + '/'+ actual_subfolder
    
    emo = os.listdir(path_to_test_emotion + actual_serie)[0]
    emo_file = path_to_test_emotion + actual_serie + '/' + emo
    with open(emo_file) as f:
        emotion = int(float(f.readline()))
        series_emotion.append(emotion)
    
    
#print(series_emotion)
#my_df = pd.DataFrame(series_emotion)
#my_df.to_csv('ck+copynewTfile/series_test_total_targetemotions.csv',header = False, index= False)

# %%
import pickle

with open('pca_shapeWNeu.pkl','rb') as f:
    pca_shape = pickle.load(f)
with open('scaler_shapeWNeu.pkl','rb') as f:
    std_scaler = pickle.load(f)

# %%
std_scaler
# Out:
# StandardScaler()

# %%
series_emotion = []
series = []

#std_scaler_instance =  StandardScaler()
for i in series_select:  
    
    actual_subject = str(i).split('/')[4]
    actual_subfolder = str(i).split('/')[5]
    actual_serie = actual_subject + '/'+ actual_subfolder
    emo = os.listdir(path_to_test_emotion + actual_serie)[0]
    emo_file = path_to_test_emotion + actual_serie + '/' + emo
    with open(emo_file) as f:
        emotion = int(float(f.readline()))
        series_emotion.append(emotion)
    series.append(actual_serie)

# %%
#Vamos por la shape feature


    
serie_landmarks, shape_test_vector, serie_shape_data  = get_shape_features(series, pca_shape, std_scaler)
#lo dejo asi, puede ser que requiera fit_transform. No sabemos.
#Ver ambas maneras, por ahora transform (Fit csv con fit)
x, y, z = shape_test_vector.shape

#a, b, c = serie_shape_data.shape
shape_test_vector =shape_test_vector.reshape(x,z)
#serie_shape_data = serie_shape_data.reshape(a,c)
# Out:
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S005', '001', 'S005_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000023.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000024.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000022.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S028', '001', 'S028_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '001', 'S042_001_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '002', 'S042_002_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '004', 'S042_004_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S042', '006', 'S042_006_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '004', 'S045_004_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000023.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000026.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000027.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000024.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000025.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000030.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000029.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000028.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S045', '005', 'S045_005_00000022.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000025.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000022.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000024.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '001', 'S046_001_00000023.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '002', 'S046_002_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '002', 'S046_002_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '002', 'S046_002_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '002', 'S046_002_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '002', 'S046_002_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '002', 'S046_002_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '003', 'S046_003_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S046', '004', 'S046_004_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '002', 'S056_002_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '003', 'S056_003_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S056', '004', 'S056_004_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '001', 'S062_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '002', 'S062_002_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000022.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000023.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000024.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '004', 'S062_004_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000028.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000022.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000029.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000026.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000025.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000023.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000024.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000027.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S062', '005', 'S062_005_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '002', 'S070_002_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '003', 'S070_003_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S070', '005', 'S070_005_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '001', 'S071_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S071', '002', 'S071_002_00000016.png']
# ...
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000024.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000033.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000023.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000041.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000032.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000027.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000037.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S501', '006', 'S501_006_00000035.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '001', 'S502_001_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000033.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000022.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000036.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000034.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000039.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000032.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000035.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000031.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000030.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000037.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000026.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000047.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000025.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000051.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000029.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000040.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000050.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000028.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000023.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000024.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000043.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000042.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000048.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000052.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000038.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000044.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000049.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000046.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000027.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000045.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S502', '004', 'S502_004_00000041.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000021.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000017.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000022.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000020.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '001', 'S504_001_00000019.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '004', 'S504_004_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000002.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000013.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000006.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000010.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000001.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000008.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000015.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000009.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000007.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000016.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000018.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000003.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000011.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000004.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000012.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000014.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000005.png']
# ['..', 'ck+copynew', 'extended-cohn-kanade-images', 'cohn-kanade-images', 'S504', '006', 'S504_006_00000017.png']

# %%
shape_test_vector.shape
# Out:
# (94, 29)

# %%
my_df = pd.DataFrame(shape_test_vector)
my_df.to_csv('pca_shapeTestWNeu.csv',header = False, index= False)

# %%
#my_df = pd.DataFrame(shape_test_vector)
#my_df.to_csv('ck+copynewTfile/pca_shapeTestingTotalnewTpoints_fearsad.csv',header = False, index= False)

# %%
serie_landmarks[1].shape
# Out:
# (24, 68, 2)

# %%
#Structure PCA

# %%
my_struct_forPCA = pd.read_csv('structure_feature_newT_vector.csv',header = None)
fear_struct_forPCA = pd.read_csv('structure_feature_newT_vector_fear.csv',header = None)
sadness_struct_forPCA = pd.read_csv('structure_feature_newT_vector_sadness.csv',header = None)
old_and_sadfear_PCA_struct = pd.concat([my_struct_forPCA, fear_struct_forPCA, sadness_struct_forPCA ])


std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(old_and_sadfear_PCA_struct)



pca_struct = PCA(n_components=13)
b_structure = pca_struct.fit_transform(scaled_landDiff)
b_structure.shape
# Out:
# (490, 13)

# %%
#old_and_sadfear_PCA = pd.read_csv('my_data_for_PCA_SNeu_AgainT_V1.csv',header = None)
#old_and_sadfear_PCA_struct = pd.read_csv('my_data_for_PCA_structure_SNeu_AgainT_V1.csv',header = None)
old_and_sadfear_PCA = pd.read_csv('my_training_data_aligned_diff_AgainT_V1.csv',header = None)
old_and_sadfear_PCA_struct = pd.read_csv('structure_feature_vector_AgainT_V1.csv',header = None)

# %%
with open('pca_structureWNeu.pkl','rb') as f:
    pca_struct = pickle.load(f)
with open('scaler_structureWNeu.pkl','rb') as f:
    std_scaler = pickle.load(f)

# %%
struct_test_vector  = get_struct_features(series, pca_struct, std_scaler,serie_landmarks, serie_shape_data)

# %%
struct_test_vector.shape
# Out:
# (94, 1, 13)

# %%
x, y,z = struct_test_vector.shape
struct_test_vector =struct_test_vector.reshape(x,z)
my_df = pd.DataFrame(struct_test_vector)
my_df.to_csv('pca_structureTestWNeu.csv',header = False, index= False)
#my_df.to_csv('ck+copynewTfile/pca_structTestingTotalnewTpoints_fearsad.csv',header = False, index= False)

# %%
#Ahora vamos con Cartoon y Texture

# %%
#Cartoon PCA
# Out:
# (94, 1, 13)

# %%
file_path = 'im_newT_cartoonarray_.csv'
chunk_size = 100

df_list = []

for chunk in pd.read_csv(file_path, chunksize=chunk_size, header = None):
    df_list.append(chunk)

df = pd.concat(df_list)

# %%
my_data_forPCA_cartoon = df
len(my_data_forPCA_cartoon)
# Out:
# 450

# %%
file_path = 'im_newT_cartoonarray_fear.csv'
fear_add = pd.read_csv(file_path,  header = None)
len(fear_add)
# Out:
# 19

# %%
file_path = 'im_newT_cartoonarray_sadness.csv'
sadness_add = pd.read_csv(file_path,  header = None)
len(sadness_add)
# Out:
# 21

# %%
my_data_for_PCA_cartoon_fearsad = pd.concat([my_data_forPCA_cartoon, fear_add, sadness_add ])
len(my_data_for_PCA_cartoon_fearsad)
# Out:
# 490

# %%
std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(my_data_for_PCA_cartoon_fearsad)
scaled_landDiff.shape
# Out:
# (490, 168100)

# %%
pca_cartoon = PCA(n_components=100)#era 14
b_cartoon = pca_cartoon.fit_transform(scaled_landDiff)
b_cartoon.shape #
# Out:
# (490, 100)

# %%
#with open('scaler_V1SNeutralsCartoon.pkl', 'rb') as pickle_file:
#    std_scaler = pickle.load(pickle_file) pca_V1SNeutralsCartoon.pkl
import pickle
with open('scaler_cartoonWNeu.pkl', 'rb') as pickle_file:
    std_scaler = pickle.load(pickle_file)


with open('pca_cartoonWNeu.pkl', 'rb') as pickle_file:
    pca_cartoon = pickle.load(pickle_file)
# Out:
# /home/imagenes/anaconda3/envs/imgEnv/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/imagenes/anaconda3/envs/imgEnv/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator PCA from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
cartoon_test_vector  = get_cartoon_features(series, pca_cartoon, std_scaler)
# Out:
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S005/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S005/001/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S028/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S028/001/cartoonimg23.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/001/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/002/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/004/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/006/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S045/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S045/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S045/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S045/005/cartoonimg29.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/001/cartoonimg24.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/002/cartoonimg5.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/003/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/004/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S056/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S056/002/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S056/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S056/003/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S056/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S056/004/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/001/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/002/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/004/cartoonimg23.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/005/cartoonimg28.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S070/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S070/002/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S070/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S070/003/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S070/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S070/005/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/001/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/002/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/004/cartoonimg27.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/005/cartoonimg20.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/006/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S073/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S073/001/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S073/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S073/006/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S076/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S076/001/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S076/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S076/005/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S076/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S076/006/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S079/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S079/001/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S079/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S079/002/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S079/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S079/004/cartoonimg25.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S083/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S083/003/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S084/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S084/001/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S084/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S084/002/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S085/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S085/002/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S085/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S085/003/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S085/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S085/004/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S086/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S086/001/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S086/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S086/002/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S089/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S089/001/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S089/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S089/002/cartoonimg20.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S089/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S089/003/cartoonimg35.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S090/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S090/002/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S090/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S090/006/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S090/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S090/007/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S094/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S094/001/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S094/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S094/004/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S098/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S098/003/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S098/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S098/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S105/008/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S105/008/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S107/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S107/001/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S107/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S107/005/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S111/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S111/001/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S111/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S111/006/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S111/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S111/007/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S114/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S114/001/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S114/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S114/006/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S116/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S116/001/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S116/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S116/006/cartoonimg6.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S116/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S116/007/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S127/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S127/001/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S127/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S127/004/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S127/010/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S127/010/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/001/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/007/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/009/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/009/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/012/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/012/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/013/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/013/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/002/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/003/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/005/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/006/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/008/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/008/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S134/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S134/003/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S134/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S134/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S134/008/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S134/008/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S135/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S135/001/cartoonimg38.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S135/012/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S135/012/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/001/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/004/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/005/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/007/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S501/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S501/001/cartoonimg66.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S501/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S501/004/cartoonimg55.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S501/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S501/006/cartoonimg40.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S502/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S502/001/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S502/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S502/004/cartoonimg51.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S504/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S504/001/cartoonimg21.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S504/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S504/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S504/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S504/006/cartoonimg17.png']

# %%
x, y,z = cartoon_test_vector.shape
cartoon_test_vector =cartoon_test_vector.reshape(x,z)
my_df = pd.DataFrame(cartoon_test_vector)
my_df.to_csv('pca_cartoonTestWNeu.csv',header = False, index= False)

# %%
cartoon_test_vector.shape
# Out:
# (94, 100)

# %%
#PCA Texture

# %%
file_path = 'im_newT_texturearray_.csv'
chunk_size = 100

df_list = []

for chunk in pd.read_csv(file_path, chunksize=chunk_size, header = None):
    df_list.append(chunk)

df2 = pd.concat(df_list)

# %%
my_data_forPCA_texture =df2

# %%
file_path = 'im_newT_texturearray_fear.csv'
fear_add = pd.read_csv(file_path,  header = None)
len(fear_add)
# Out:
# 19

# %%
file_path = 'im_newT_texturearray_sadness.csv'
sadness_add = pd.read_csv(file_path,  header = None)
len(sadness_add)
# Out:
# 21

# %%
my_data_for_PCA_texture_fearsad = pd.concat([my_data_forPCA_texture, fear_add, sadness_add ])
len(my_data_for_PCA_texture_fearsad)
# Out:
# 490

# %%
std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(my_data_for_PCA_texture_fearsad)
scaled_landDiff.shape
# Out:
# (490, 168100)

# %%
pca_texture = PCA(n_components=350)#era 14
b_texture = pca_texture.fit_transform(scaled_landDiff)
b_texture.shape #
# Out:
# (490, 350)

# %%
#with open('scaler_V1SNeutralsTexture.pkl', 'rb') as pickle_file:
#    std_scaler = pickle.load(pickle_file)
with open('scaler_textureWNeu.pkl', 'rb') as pickle_file:
    std_scaler = pickle.load(pickle_file)


with open('pca_textureWNeu.pkl', 'rb') as pickle_file:
    pca_texture = pickle.load(pickle_file)
# Out:
# /home/imagenes/anaconda3/envs/imgEnv/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/imagenes/anaconda3/envs/imgEnv/lib/python3.11/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator PCA from version 1.3.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
texture_test_vector  = get_texture_features(series, pca_texture, std_scaler)
# Out:
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)
# (410, 410)

# %%
x, y,z = texture_test_vector.shape
texture_test_vector =texture_test_vector.reshape(x,z)
my_df = pd.DataFrame(texture_test_vector)
my_df.to_csv('pca_textureTestWNeu.csv',header = False, index= False)

# %%
texture_test_vector.shape
# Out:
# (94, 250)

# %%
def get_texture_features(series, pca, scaler):
    texture_features = []    
    for s in range(0, len(series)):
        texture_f = get_texture_f(series[s], pca, scaler)        
        texture_features.append(texture_f)        
    texture_features = np.asarray(texture_features)
    return texture_features

# %%
def  get_texture_f(s, pca, scaler):    
    sub = s.split('/')[0]
    em = s.split('/')[1]
    warpimgpath = 'ck+copynewTfile/transformed_test_images_total/' + s + '/'
    first = "1"
    last = str(len(os.listdir(warpimgpath))-1)    
    image_first = sub + '_' + em + '_' + first.zfill(8)
    image_last = sub + '_' + em + '_' + last.zfill(8)    
    imagepathfirst = warpimgpath +'warped_image_procustres_'+ image_first + '.png'
    imagepath = warpimgpath +'warped_image_procustres_'+ image_last + '.png'
    
    #warpimgpath = 'ck+copynewTfile/transformed_test_images_total/' + s + '/'
    #imagepathfirst = warpimgpath +'/warped_image_procustres_'+ str(0) + '.png'
    #imagepath = warpimgpath +'/warped_image_procustres_'+ str(len(os.listdir(warpimgpath))-1) + '.png'
    
    img = cv2.imread(imagepath)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = img[40:450, 170:580]
    print(img2.shape)
   
    texture_e = "ck+copynewTfile/texture_training_test_total/" + s +"/textureimg"  + str(len(os.listdir(warpimgpath))-1) +".png"
    
    
    
    imtext = []

    texture_images = np.asarray([texture_e])
    for i in texture_images:
        img = cv2.imread(i, cv2.IMREAD_GRAYSCALE)    
        imtext.append(img.flatten())
    
    imtextarray = np.asarray(imtext)  
    

    
    test_texture_data = imtextarray.reshape(1,-1)    
    scaled_inst = scaler.transform(test_texture_data)
    b_texture_instance = pca.transform(scaled_inst)
    
    
    
    return b_texture_instance

# %%
def get_cartoon_features(series, pca, scaler):
    cartoon_features = []    
    for s in range(0, len(series)):
        cartoon_f = get_cartoon_f(series[s], pca, scaler)        
        cartoon_features.append(cartoon_f)        
    cartoon_features = np.asarray(cartoon_features)
    return cartoon_features

# %%
import subprocess
# !chmod a+x '../cartoonTexture'

# %%
import subprocess
# !chmod a+x '../cartoonTexture'
cartoon_test_vector  = get_cartoon_features(series, pca_cartoon, std_scaler)
# Out:
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S005/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S005/001/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S028/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S028/001/cartoonimg23.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/001/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/002/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/004/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S042/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S042/006/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S045/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S045/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S045/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S045/005/cartoonimg29.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/001/cartoonimg24.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/002/cartoonimg5.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/003/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S046/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S046/004/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S056/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S056/002/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S056/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S056/003/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S056/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S056/004/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/001/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/002/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/004/cartoonimg23.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S062/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S062/005/cartoonimg28.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S070/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S070/002/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S070/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S070/003/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S070/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S070/005/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/001/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/002/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/004/cartoonimg27.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/005/cartoonimg20.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S071/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S071/006/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S073/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S073/001/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S073/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S073/006/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S076/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S076/001/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S076/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S076/005/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S076/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S076/006/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S079/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S079/001/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S079/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S079/002/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S079/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S079/004/cartoonimg25.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S083/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S083/003/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S084/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S084/001/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S084/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S084/002/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S085/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S085/002/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S085/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S085/003/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S085/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S085/004/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S086/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S086/001/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S086/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S086/002/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S089/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S089/001/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S089/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S089/002/cartoonimg20.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S089/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S089/003/cartoonimg35.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S090/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S090/002/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S090/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S090/006/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S090/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S090/007/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S094/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S094/001/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S094/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S094/004/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S098/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S098/003/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S098/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S098/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S105/008/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S105/008/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S107/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S107/001/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S107/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S107/005/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S111/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S111/001/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S111/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S111/006/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S111/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S111/007/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S114/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S114/001/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S114/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S114/006/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S116/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S116/001/cartoonimg13.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S116/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S116/006/cartoonimg6.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S116/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S116/007/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S127/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S127/001/cartoonimg16.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S127/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S127/004/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S127/010/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S127/010/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/001/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/007/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/009/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/009/cartoonimg18.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/012/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/012/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S130/013/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S130/013/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/002/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/002/cartoonimg17.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/003/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/005/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/006/cartoonimg22.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S132/008/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S132/008/cartoonimg9.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S134/003/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S134/003/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S134/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S134/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S134/008/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S134/008/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S135/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S135/001/cartoonimg38.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S135/012/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S135/012/cartoonimg19.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/001/cartoonimg11.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/004/cartoonimg12.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/005/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/005/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S138/007/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S138/007/cartoonimg10.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S501/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S501/001/cartoonimg66.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S501/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S501/004/cartoonimg55.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S501/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S501/006/cartoonimg40.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S502/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S502/001/cartoonimg15.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S502/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S502/004/cartoonimg51.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S504/001/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S504/001/cartoonimg21.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S504/004/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S504/004/cartoonimg14.png']
# (410, 410)
# ['ck+copynewTfile/cartoon_training_test_total/S504/006/cartoonimg0.png'
#  'ck+copynewTfile/cartoon_training_test_total/S504/006/cartoonimg17.png']

# %%
def  get_cartoon_f(s, pca, scaler):    
    sub = s.split('/')[0]
    em = s.split('/')[1]
    warpimgpath = 'ck+copynewTfile/transformed_test_images_total/' + s + '/'
    first = "1"
    last = str(len(os.listdir(warpimgpath))-1)    
    image_first = sub + '_' + em + '_' + first.zfill(8)
    image_last = sub + '_' + em + '_' + last.zfill(8)    
    imagepathfirst = warpimgpath +'warped_image_procustres_'+ image_first + '.png'
    imagepath = warpimgpath +'warped_image_procustres_'+ image_last + '.png'
    
    img = cv2.imread(imagepath)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = img[40:450, 170:580]
    print(img2.shape)

    if not os.path.exists("ck+copynewTfile/cartoon_training_test_total/" + s):
        # Create the directory
        os.makedirs("ck+copynewTfile/cartoon_training_test_total/"+ s)
    if not os.path.exists("ck+copynewTfile/texture_training_test_total/" + s):
        # Create the directory
        os.makedirs("ck+copynewTfile/texture_training_test_total/" +s)

    
    cv2.imwrite("croppedimg_test.png", img2)
    cartoon_path = "ck+copynewTfile/cartoon_training_test_total/" + s +"/cartoonimg" + str(len(os.listdir(warpimgpath))-1) +".png"
    texture_path = "ck+copynewTfile/texture_training_test_total/"+ s +"/textureimg" + str(len(os.listdir(warpimgpath))-1)+".png"
    subprocess.check_output(['../cartoonTexture',"croppedimg_test.png", "0.2", cartoon_path, texture_path])


    #cartoon, texture = cartoonTexture_grey(img2, 0.2, 50, 0.35, 0.35, 1.0, 0)
    #cv2.imwrite("ck+copynewTfile/cartoon_training_test_total/" + s +"/cartoonimg" + str(len(os.listdir(warpimgpath))-1) +".png", cartoon)
    #cv2.imwrite("ck+copynewTfile/texture_training_test_total/"+ s +"/textureimg" + str(len(os.listdir(warpimgpath))-1)+".png", texture)
    
    img = cv2.imread(imagepathfirst)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img2 = img[40:450, 170:580]

    cv2.imwrite("croppedimg_test.png", img2)
    cartoon_path = "ck+copynewTfile/cartoon_training_test_total/" + s +"/cartoonimg" + str(0) +".png"
    texture_path = "ck+copynewTfile/texture_training_test_total/" +s +"/textureimg" + str(0)+".png"
    subprocess.check_output(['../cartoonTexture',"croppedimg_test.png", "0.2", cartoon_path, texture_path])


    #cartoon, texture = cartoonTexture_grey(img2, 0.2, 50, 0.35, 0.35, 1.0, 0)
    #cv2.imwrite("ck+copynewTfile/cartoon_training_test_total/" + s +"/cartoonimg" + str(0) +".png", cartoon)
    #cv2.imwrite("ck+copynewTfile/texture_training_test_total/" +s +"/textureimg" + str(0)+".png", texture)
   
    cartoon_f = "ck+copynewTfile/cartoon_training_test_total/" + s +"/cartoonimg" + str(0) +".png"
    cartoon_e = "ck+copynewTfile/cartoon_training_test_total/" + s +"/cartoonimg" + str(len(os.listdir(warpimgpath))-1) +".png"
    texture_e = "ck+copynewTfile/texture_training_test_total/" + s +"/textureimg"  + str(len(os.listdir(warpimgpath))-1) +".png"
    
    imcart = []
    cartoon_images = np.asarray([cartoon_f, cartoon_e])
    print(cartoon_images)
    for i in cartoon_images:
        img = cv2.imread(i, cv2.IMREAD_GRAYSCALE)
        img_mean = img/np.mean(img)
        imcart.append(img_mean.flatten())
    
    imcartoon = np.asarray(imcart)
    imcartooncopy = []
    for i in range(0, len(imcartoon) ):
        imca = imcartoon[i] - imcartoon[0]
        imcartooncopy.append(np.asarray(imca))

    imcartoonarray = np.asarray(imcartooncopy)
    
    test_cartoon_data = imcartoonarray[1].reshape(1,-1)
    
    scaled_inst = scaler.transform(test_cartoon_data)
    b_cartoon_instance = pca.transform(scaled_inst)
    
    
    
    return  b_cartoon_instance

# %%
x, y,z = cartoon_test_vector.shape
cartoon_test_vector =cartoon_test_vector.reshape(x,z)
my_df = pd.DataFrame(cartoon_test_vector)
my_df.to_csv('ck+copynewTfile/pca_cartoonTestingnewTpoints_.csv',header = False, index= False)

# %%
def get_struct_features(series, pca, scaler, serie_landmarks, serie_shape_data):
    struct_features = []    
    for s in range(0, len(series)):
        struct_f = get_struct_f(series[s], pca, scaler, serie_landmarks[s], serie_shape_data[s])        
        struct_features.append(struct_f)        
    struct_features = np.asarray(struct_features)
    #serie_landmarks = np.asarray(serie_landmarks)
    return struct_features

# %%
def get_struct_f(s, pca, scaler, one_serie_landmark, serie_data):
    pathi = 'ck+copynewTfile/transformed_test_images_total/' + s + '/'
    firsti = pathi + '/' +np.sort(os.listdir(pathi))[0]    
    first_frame = np.asarray([one_serie_landmark[0]])    
    first_images = np.asarray([firsti])
    struct_test = get_21_points(first_frame, first_images)
    last_point = get_emotion_intensity(old_and_sadfear_PCA, serie_data)
    structre_test_f =np.append(struct_test,last_point )
    
    test_struc_data = structre_test_f.reshape(1,-1)    
    scaled_inst = scaler.transform(test_struc_data)
    

    b_structure_instance = pca.transform(scaled_inst)
    
    return b_structure_instance

# %%
serie_shape_data.shape
# Out:
# (20, 136)

# %%
def get_emotion_intensity(my_data_forPCA, serie_shape_data):
    Ai = my_data_forPCA.max()
    data_2_intensity_div = serie_shape_data.flatten()/Ai
    data_2_intensity_sum =  np.sum(data_2_intensity_div)
    data_2_intensity_final = data_2_intensity_sum/136
    return data_2_intensity_final

# %%
def get_21_points(first_frame, first_images ):
    first_feature_point = list_get_feature_point(first_frame, 1, first_images)
    second_feature_point = list_get_feature_point(first_frame, 2, first_images)
    third_feature_point = list_get_feature_point(first_frame, 3, first_images)
    fourth_feature_point = list_get_feature_point(first_frame, 4, first_images)
    five_feature_point = list_get_feature_point(first_frame, 5, first_images)
    six_feature_point = list_get_feature_point(first_frame, 6, first_images)
    seven_feature_point = list_get_feature_point(first_frame, 7, first_images)
    eight_feature_point = list_get_feature_point(first_frame, 8, first_images)
    nine_feature_point = list_get_feature_point(first_frame, 9, first_images)
    ten_feature_point = list_get_feature_point(first_frame, 10, first_images)
    eleven_feature_point = list_get_feature_point(first_frame, 11, first_images)
    twelve_feature_point = list_get_feature_point(first_frame, 12, first_images)
    thirteen_feature_point = list_get_feature_point(first_frame, 13, first_images)
    fourteen_feature_point = list_get_feature_point(first_frame, 14, first_images)
    fifteen_feature_point = list_get_feature_point(first_frame, 15, first_images)
    sixteen_feature_point = list_get_feature_point(first_frame, 16, first_images)
    seventeen_feature_point = list_get_feature_point(first_frame, 17, first_images)
    eigtheen_feature_point = list_get_feature_point(first_frame, 18, first_images)
    nineteen_feature = list_get_feature_point(first_frame, 19, first_images)
    twenty_feature = list_get_feature_point(first_frame, 20, first_images)
    twentyone_feature = list_get_feature_point(first_frame, 21, first_images)
    
    structure_vector = first_feature_point
    structure_vector = np.vstack((structure_vector, second_feature_point))
    structure_vector = np.vstack((structure_vector, third_feature_point))
    structure_vector = np.vstack((structure_vector, fourth_feature_point))
    structure_vector = np.vstack((structure_vector, five_feature_point))
    structure_vector = np.vstack((structure_vector, six_feature_point))
    structure_vector = np.vstack((structure_vector, seven_feature_point))
    structure_vector = np.vstack((structure_vector, eight_feature_point))
    structure_vector = np.vstack((structure_vector, nine_feature_point))
    structure_vector = np.vstack((structure_vector, ten_feature_point))
    structure_vector = np.vstack((structure_vector, eleven_feature_point))
    structure_vector = np.vstack((structure_vector, twelve_feature_point))
    structure_vector = np.vstack((structure_vector, thirteen_feature_point))
    structure_vector = np.vstack((structure_vector, fourteen_feature_point))
    structure_vector = np.vstack((structure_vector, fifteen_feature_point))
    structure_vector = np.vstack((structure_vector, sixteen_feature_point))
    structure_vector = np.vstack((structure_vector, seventeen_feature_point))
    structure_vector = np.vstack((structure_vector, eigtheen_feature_point))
    structure_vector = np.vstack((structure_vector, nineteen_feature))
    structure_vector = np.vstack((structure_vector, twenty_feature))
    structure_vector = np.vstack((structure_vector, twentyone_feature))
    
    structre_features = np.asarray(structure_vector).flatten().T
    return structre_features

# %%
#b_shape = pd.read_csv('pca_training_shapepoints_newT.csv',header = None)
#b_shape

# %%
#b_shape = pd.read_csv('pca_shapepoints.csv',header = None)
#b_shape

# %%
#landmarks, shape_fea = get_shape_features(series[0:2], pca_shape, std_scaler_instance )

# %%
#landmarks[0].shape
# Out:
# (14, 68, 2)

# %%
#shape_fea.reshape(2,29)
# Out:
# array([[ 1.31761163e-17, -8.46133663e-17,  1.02522191e-17,
#          2.48999310e-17, -5.92633616e-17, -4.21758387e-17,
#         -2.74159661e-19,  6.97939031e-18,  8.07992736e-18,
#          5.94490542e-17,  3.24739899e-17,  2.06684422e-18,
#          3.24723444e-17, -5.74443291e-17, -3.32178148e-17,
#         -1.45244305e-17, -2.78273743e-17,  4.35890223e-17,
#         -6.63422246e-18,  1.71194123e-17,  1.14750728e-17,
#          4.42816110e-17,  7.95650766e-17, -5.73616061e-17,
#         -8.13343645e-18, -4.56504349e-17, -1.32944873e-17,
#         -8.27537852e-18,  3.10928033e-17],
#        [ 1.31761163e-17, -8.46133663e-17,  1.02522191e-17,
#          2.48999310e-17, -5.92633616e-17, -4.21758387e-17,
#         -2.74159661e-19,  6.97939031e-18,  8.07992736e-18,
#          5.94490542e-17,  3.24739899e-17,  2.06684422e-18,
#          3.24723444e-17, -5.74443291e-17, -3.32178148e-17,
#         -1.45244305e-17, -2.78273743e-17,  4.35890223e-17,
#         -6.63422246e-18,  1.71194123e-17,  1.14750728e-17,
#          4.42816110e-17,  7.95650766e-17, -5.73616061e-17,
#         -8.13343645e-18, -4.56504349e-17, -1.32944873e-17,
#         -8.27537852e-18,  3.10928033e-17]])

# %%
def get_shape_features(series, pca, scaler):
    shape_features = []
    serie_landmarks = []
    serie_shape_data = []
    for s in series:
        feature_landmarks, shape_f, test_s_data = get_shape_f(s, pca, scaler)        
        shape_features.append(shape_f)
        serie_landmarks.append(feature_landmarks)
        serie_shape_data.append(test_s_data)
    shape_features = np.asarray(shape_features)
    serie_shape_data = np.asarray(serie_shape_data)
    return serie_landmarks, shape_features, serie_shape_data

# %%
def get_shape_f(serie, pca,scaler):
    image_path =  '../ck+copynew/extended-cohn-kanade-images/cohn-kanade-images/' + serie
    land_path = '../ck+copynew/Landmarks/' + serie
    
    test_images = []
    test_land = []
    
    files = Path(image_path).rglob("*")
    for file in files:
        print(os.path.normpath(file).split(os.path.sep))
        if len(os.path.normpath(file).split(os.path.sep)[6].split('_')) == 3:
            test_images.append(str(file))
            
    files = Path(land_path).rglob("*")
    for file in files:
        if len(os.path.normpath(file).split(os.path.sep)[5].split('_')) == 4:
            test_land.append(str(file))
    
    test_images = np.sort(test_images)
    test_land = np.sort(test_land)
    
    transformed_landmarks_total, test_shape_data = get_test_shape_data(test_images, test_land, serie)
    test_shape_data = test_shape_data.reshape(1,-1)
    
    scaled_inst = scaler.transform(test_shape_data)
    b_shape_instance = pca.transform(scaled_inst)  
    
    return transformed_landmarks_total, b_shape_instance, test_shape_data

# %%
#get_shape_f('S005/001', pca_shape, std_scaler_instance)

# %%
def get_test_shape_data(test_images, test_land, serie):
    landmarks_seqXY = get_landmarks_of_folder(test_land)
    cant_de_frames = len(landmarks_seqXY)
    intercalated_data = intercalate_data_of_vectors(landmarks_seqXY, 0)
    pathi = 'ck+copynewTfile/transformed_test_images_total/' + serie + '/'
    
    if not os.path.exists(pathi):
        # Create the directory
        os.makedirs(pathi)
    reference_image_path = 'ck+copynewTfile/reference_image.png'
    my_landmark_for_ref = pd.read_csv('ck+copynewTfile/cknewT_landmark_intercalated_data.csv',header = None)
    reference_land = my_landmark_for_ref.iloc[0]
    transformed_landmarks_total = align_and_transform_vector_of_images(reference_image_path, reference_land, intercalated_data, test_images, pathi)
    transformed_final = transformed_landmarks_total[0].flatten('F')
    for i in range (1, len(transformed_landmarks_total)):
        transformed_final = np.vstack((transformed_final, transformed_landmarks_total[i].flatten('F')))
    nd =0
    my_data_aligned_diff =[]
    for i in range(0, cant_de_frames):#51
        my_data_aligned_diff.append(transformed_final[i]- transformed_final[0]) #no dice nada de abs
    my_data_aligned_diff = np.asarray(my_data_aligned_diff)

    test_shape_data = my_data_aligned_diff[len(my_data_aligned_diff) -1]
    return transformed_landmarks_total, test_shape_data

# %%
test_images = []



image_path = '/home/alicia/Documentos/Tesis2023/SynthesisEmotions/ck+copynew/extended-cohn-kanade-images/cohn-kanade-images/S005/001'
files = Path(image_path).rglob("*")
for file in files:
    if len(os.path.normpath(file).split(os.path.sep)[11].split('_')) == 3:        
        test_images.append(str(file))

emo_file = '/home/alicia/Documentos/Tesis2023/SynthesisEmotions/ck+copynew/Emotion_labels/Emotion/S005/001/S005_001_00000011_emotion.txt'

with open(emo_file) as f:
  emotion = int(float(f.readline()))
  test_images_labels[0] = emotion

land_files  = []

image_path = '/home/alicia/Documentos/Tesis2023/SynthesisEmotions/ck+copynew/Landmarks/S005/001'
files = Path(image_path).rglob("*")
for file in files:    
    if len(os.path.normpath(file).split(os.path.sep)[10].split('_')) == 4:
        land_files.append(str(file))


test_images = np.sort(test_images)
land_files = np.sort(land_files)
len(land_files)
# Out:
# 11

# %%
landmarks_seqXY = get_landmarks_of_folder(land_files)
cant_de_frames = len(landmarks_seqXY)
cant_de_frames
intercalated_data = intercalate_data_of_vectors(landmarks_seqXY, 0)
pathi = 'ck+copynewTfile/transformed_test_total_images/'

if not os.path.exists(pathi):
    # Create the directory
    os.makedirs(pathi)
reference_image_path = 'ck+copynewTfile/reference_image.png'
my_landmark_for_ref = pd.read_csv('ck+copynewTfile/cknewT_landmark_intercalated_data.csv',header = None)
reference_land = my_landmark_for_ref.iloc[0]
transformed_landmarks_total = align_and_transform_vector_of_images(reference_image_path, reference_land, intercalated_data, test_images, pathi)

transformed_final = transformed_landmarks_total[0].flatten('F')
for i in range (1, len(transformed_landmarks_total)):
    transformed_final = np.vstack((transformed_final, transformed_landmarks_total[i].flatten('F')))


nd =0
my_data_aligned_diff =[]
for i in range(0, cant_de_frames):#51
    my_data_aligned_diff.append(transformed_final[i]- transformed_final[0]) #no dice nada de abs
my_data_aligned_diff = np.asarray(my_data_aligned_diff)

test_shape_data = my_data_aligned_diff[len(my_data_aligned_diff) -1]
#PCA DEBAJO

# %%
transformed_final.shape
# Out:
# (11, 136)

# %%
#Ahora hacemos PCA con este vector
# Out:
# (136,)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

my_data_forPCA = pd.read_csv('my_training_data_aligned_diff.csv',header = None)

std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(my_data_forPCA)
scaled_landDiff.shape

pca_shape = PCA(n_components=29)
b_shape = pca_shape.fit_transform(scaled_landDiff)
b_shape.shape
# Out:
# (3614, 29)

# %%
test_shape_data = test_shape_data.reshape(1,-1)
std_scaler_instance =  StandardScaler()
scaled_inst = std_scaler_instance.fit_transform(test_shape_data)
scaled_inst.shape
# Out:
# (1, 136)

# %%
b_shape_instance = pca_shape.transform(scaled_inst)
b_shape_instance.shape
# Out:
# (1, 29)

# %% [markdown]
# # Ahora vamos con structure

# %%
transformed_landmarks_total.shape
# Out:
# (11, 68, 2)

# %%
transformed_landmarks_total.shape # necesitamos los landmarks en [x, y]


firsti = pathi + '/' +np.sort(os.listdir(pathi))[0]

first_frame = np.asarray([transformed_landmarks_total[0]])
first_images = np.asarray([firsti])

# %%
first_feature_point = list_get_feature_point(first_frame, 1, first_images)
second_feature_point = list_get_feature_point(first_frame, 2, first_images)
third_feature_point = list_get_feature_point(first_frame, 3, first_images)
fourth_feature_point = list_get_feature_point(first_frame, 4, first_images)
five_feature_point = list_get_feature_point(first_frame, 5, first_images)
six_feature_point = list_get_feature_point(first_frame, 6, first_images)
seven_feature_point = list_get_feature_point(first_frame, 7, first_images)
eight_feature_point = list_get_feature_point(first_frame, 8, first_images)
nine_feature_point = list_get_feature_point(first_frame, 9, first_images)
ten_feature_point = list_get_feature_point(first_frame, 10, first_images)
eleven_feature_point = list_get_feature_point(first_frame, 11, first_images)
twelve_feature_point = list_get_feature_point(first_frame, 12, first_images)
thirteen_feature_point = list_get_feature_point(first_frame, 13, first_images)
fourteen_feature_point = list_get_feature_point(first_frame, 14, first_images)
fifteen_feature_point = list_get_feature_point(first_frame, 15, first_images)
sixteen_feature_point = list_get_feature_point(first_frame, 16, first_images)
seventeen_feature_point = list_get_feature_point(first_frame, 17, first_images)
eigtheen_feature_point = list_get_feature_point(first_frame, 18, first_images)
nineteen_feature = list_get_feature_point(first_frame, 19, first_images)
twenty_feature = list_get_feature_point(first_frame, 20, first_images)
twentyone_feature = list_get_feature_point(first_frame, 21, first_images)

# %%
structure_vector = first_feature_point
structure_vector = np.vstack((structure_vector, second_feature_point))
structure_vector = np.vstack((structure_vector, third_feature_point))
structure_vector = np.vstack((structure_vector, fourth_feature_point))
structure_vector = np.vstack((structure_vector, five_feature_point))
structure_vector = np.vstack((structure_vector, six_feature_point))
structure_vector = np.vstack((structure_vector, seven_feature_point))
structure_vector = np.vstack((structure_vector, eight_feature_point))
structure_vector = np.vstack((structure_vector, nine_feature_point))
structure_vector = np.vstack((structure_vector, ten_feature_point))
structure_vector = np.vstack((structure_vector, eleven_feature_point))
structure_vector = np.vstack((structure_vector, twelve_feature_point))
structure_vector = np.vstack((structure_vector, thirteen_feature_point))
structure_vector = np.vstack((structure_vector, fourteen_feature_point))
structure_vector = np.vstack((structure_vector, fifteen_feature_point))
structure_vector = np.vstack((structure_vector, sixteen_feature_point))
structure_vector = np.vstack((structure_vector, seventeen_feature_point))
structure_vector = np.vstack((structure_vector, eigtheen_feature_point))
structure_vector = np.vstack((structure_vector, nineteen_feature))
structure_vector = np.vstack((structure_vector, twenty_feature))
structure_vector = np.vstack((structure_vector, twentyone_feature))

# %%
structre_features = np.asarray(structure_vector).flatten().T
structre_features.shape
# Out:
# (21,)

# %%
Ai = my_data_forPCA.max()

# %%
test_shape_data.T
# Out:
# array([[-2.13044903e+00],
#        [-2.09843077e+00],
#        [-2.04936478e+00],
#        [-1.80733321e+00],
#        [-1.54617137e+00],
#        [ 3.92520230e-01],
#        [ 9.29445312e-01],
#        [ 2.00847281e-01],
#        [ 7.89640622e-01],
#        [ 1.89898945e-01],
#        [-3.19994025e-01],
#        [-7.59037758e-01],
#        [ 5.06418766e-01],
#        [ 5.06728188e+00],
#        [ 3.21106435e+00],
#        [ 2.77136044e+00],
#        [ 2.73026498e+00],
#        [-1.38520767e+00],
#        [ 4.29521874e-01],
#        [ 5.36783258e-01],
#        [ 1.83214475e-01],
#        [-2.46329583e+00],
#        [-2.14251240e+00],
#        [-3.82483246e+00],
#        [-2.27591092e+00],
#        [ 3.04810214e-01],
#        [ 2.18522220e+00],
#        [ 1.51464518e+00],
#        [ 7.03510862e-01],
#        [ 5.97880833e-01],
#        [-2.29652546e+00],
#        [-1.23195424e+00],
#        [-1.45015848e+00],
#        [-7.33942067e-01],
#        [ 1.26826281e+00],
#        [ 2.18496909e+00],
#        [-1.13695468e+00],
#        [-2.81604531e+00],
#        [-4.32888512e+00],
#        [-3.43374360e+00],
#        [-2.58797303e+00],
#        [-1.72462079e+00],
#        [ 4.51910572e+00],
#        [ 6.78864746e+00],
#        [ 5.80091203e+00],
#        [ 5.33328776e+00],
#        [ 4.21833767e+00],
#        [ 4.40795413e+00],
#        [-5.42078202e-02],
#        [-3.47154679e+00],
#        [-1.40501428e+00],
#        [-1.22020052e+00],
#        [-7.10030680e-01],
#        [ 6.12529964e-01],
#        [-1.93965345e+00],
#        [-1.13485115e-02],
#        [ 2.52238995e-01],
#        [ 3.70027219e-01],
#        [-1.28122011e-01],
#        [-5.72124382e-01],
#        [-1.27774086e-01],
#        [-1.91408849e-01],
#        [-7.00096455e-01],
#        [-1.17672894e+00],
#        [-1.56117928e+00],
#        [-1.01727829e+00],
#        [-2.08684467e-01],
#        [ 3.81372494e-02],
#        [ 6.04048748e-01],
#        [ 1.21548830e+00],
#        [ 1.47368554e+00],
#        [ 2.02559918e+00],
#        [ 2.58826100e+00],
#        [ 1.60082911e+00],
#        [ 1.54794539e+00],
#        [ 3.82656927e+00],
#        [ 3.81647322e+00],
#        [ 9.80948013e-01],
#        [-1.19322381e+00],
#        [-1.94276128e+00],
#        [-8.13800428e-01],
#        [ 6.38807194e-01],
#        [ 4.54207633e-01],
#        [ 4.61504317e-01],
#        [ 2.23435692e-01],
#        [-2.21833614e+00],
#        [ 1.17049689e+00],
#        [ 3.51426404e+00],
#        [ 5.06056925e+00],
#        [ 9.42372080e+00],
#        [ 1.48182861e+01],
#        [ 7.21742940e+00],
#        [ 4.07885343e+00],
#        [-6.06784368e-01],
#        [-5.65704580e-01],
#        [ 4.88596733e+00],
#        [ 5.14427616e+00],
#        [ 5.44509021e+00],
#        [ 5.94388282e+00],
#        [-6.59534909e+00],
#        [-3.80629915e+00],
#        [-1.53243012e+00],
#        [-2.58392840e+00],
#        [-5.69311074e+00],
#        [ 3.53566180e-01],
#        [ 1.50447834e+00],
#        [ 3.13652905e+00],
#        [-1.93783127e+00],
#        [-3.79315602e+00],
#        [-4.18085883e+00],
#        [-1.05978190e+00],
#        [ 3.80578061e+00],
#        [ 2.61358595e+00],
#        [-2.37373355e-01],
#        [-5.21511251e+00],
#        [-6.27462460e+00],
#        [-3.35883515e+00],
#        [-6.76240668e+00],
#        [-3.39177984e+00],
#        [-2.25183066e+00],
#        [-1.37288057e+00],
#        [-4.48074547e+00],
#        [-2.07535851e+00],
#        [-1.13837304e+00],
#        [-9.14720050e-01],
#        [-2.15955122e+00],
#        [-2.79215915e+00],
#        [-2.60567822e+00],
#        [-1.91855215e+00],
#        [-1.92828240e+00],
#        [-2.48761449e+00],
#        [-1.58299619e+00],
#        [-1.60213037e+00],
#        [-1.58636335e+00],
#        [-2.97546047e+00],
#        [-1.93839462e+00]])

# %%
test_shape_data.flatten()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 test_shape_data.flatten().shape
#
# NameError: name 'test_shape_data' is not defined

# %%
Ai.shape
# Out:
# (136,)

# %%
data_2_intensity_div = test_shape_data.flatten()/Ai
data_2_intensity_sum =  np.sum(data_2_intensity_div)
data_2_intensity_final = data_2_intensity_sum/136
data_2_intensity_final
# Out:
# -0.020026992286394683

# %%
emotionIn = data_2_intensity_final
structre_features =np.append(structre_features,emotionIn )
structre_features.shape
# Out:
# (22,)

# %%
#Ahora hacemos PCA de estructura

# %%
my_data_forPCA_structure = pd.read_csv('structure_feature_training_vector.csv',header = None)

std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(my_data_forPCA_structure)



pca_structure = PCA(n_components=13)
b_structure = pca_structure.fit_transform(scaled_landDiff)
b_structure.shape
# Out:
# (3614, 13)

# %%
test_struc_data = structre_features.reshape(1,-1)
std_scaler_instance =  StandardScaler()
scaled_inst = std_scaler_instance.fit_transform(test_struc_data)
test_struc_data.shape

b_structure_instance = pca_structure.transform(test_struc_data)
b_structure_instance.shape
# Out:
# (1, 13)

# %%
#Ahora vamos por el cartoon y la textura

# %%
warpimgpath = 'ck+copynewTfile/transformed_test_images'

imagepathfirst = warpimgpath +'/warped_image_procustres_'+ str(0) + '.png'
imagepath = warpimgpath +'/warped_image_procustres_'+ str(len(os.listdir(warpimgpath))-1) + '.png'

img = cv2.imread(imagepath)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2 = img[40:450, 170:580]
print(img2.shape)

if not os.path.exists("ck+copynewTfile/cartoon_training_test"):
    # Create the directory
    os.makedirs("ck+copynewTfile/cartoon_training_test")
if not os.path.exists("ck+copynewTfile/texture_training_test"):
    # Create the directory
    os.makedirs("ck+copynewTfile/texture_training_test")



cartoon, texture = cartoonTexture_grey(img2, 0.2, 50, 0.35, 0.35, 1.0, 0)
cv2.imwrite("ck+copynewTfile/cartoon_training_test/cartoonimg" + str(len(os.listdir(warpimgpath))-1) +".png", cartoon)
cv2.imwrite("ck+copynewTfile/texture_training_test/textureimg" + str(len(os.listdir(warpimgpath))-1)+".png", texture)
# Out:
# (410, 410)
# True

# %%
img = cv2.imread(imagepathfirst)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2 = img[40:450, 170:580]

cartoon, texture = cartoonTexture_grey(img2, 0.2, 50, 0.35, 0.35, 1.0, 0)
cv2.imwrite("ck+copynewTfile/cartoon_training_test/cartoonimg" + str(0) +".png", cartoon)
cv2.imwrite("ck+copynewTfile/texture_training_test/textureimg" + str(0)+".png", texture)
# Out:
# True

# %%
cartoon_f = "ck+copynewTfile/cartoon_training_test/cartoonimg" + str(0) +".png"
cartoon_e = "ck+copynewTfile/cartoon_training_test/cartoonimg" + str(len(os.listdir(warpimgpath))-1) +".png"
texture_e = "ck+copynewTfile/texture_training_test/textureimg"  + str(len(os.listdir(warpimgpath))-1) +".png"

# %%
imcart = []
cartoon_images = np.asarray([cartoon_f, cartoon_e])

for i in cartoon_images:
    img = cv2.imread(i, cv2.IMREAD_GRAYSCALE)
    img_mean = img/np.mean(img)
    imcart.append(img_mean.flatten())
    
imcartoon = np.asarray(imcart)
imcartooncopy = []
for i in range(0, len(imcartoon) ):
    imca = imcartoon[i] - imcartoon[0]
    imcartooncopy.append(np.asarray(imca))

imcartoonarray = np.asarray(imcartooncopy)
imcartoonarray.shape
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
imtext = []

texture_images = np.asarray([texture_e])
for i in texture_images:
    img = cv2.imread(i, cv2.IMREAD_GRAYSCALE)    
    imtext.append(img.flatten())
    
imtextarray = np.asarray(imtext)
imtextarray.shape
# Out:
# (1, 168100)

# %%
#Cartoon PCA

# %%
file_path = 'im_newT_cartoonarray_.csv'
chunk_size = 100

df_list = []

for chunk in pd.read_csv(file_path, chunksize=chunk_size, header = None):
    df_list.append(chunk)

df = pd.concat(df_list)

# %%
my_data_forPCA = df

# %%
std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(my_data_forPCA)
scaled_landDiff.shape
# Out:
# (450, 168100)

# %%
pca_cartoon = PCA(n_components=75)#era 14
b_cartoon = pca_cartoon.fit_transform(scaled_landDiff)
b_cartoon.shape #
# Out:
# (450, 75)

# %%
test_cartoon_data = imcartoonarray[1].reshape(1,-1)
std_scaler_instance =  StandardScaler()
scaled_inst = std_scaler_instance.fit_transform(test_cartoon_data)


b_cartoon_instance = pca_cartoon.transform(scaled_inst)
b_cartoon_instance.shape
# Out:
# (1, 75)

# %%
#Texture PCA

# %%
file_path = 'im_newT_texturearray_.csv'
chunk_size = 100

df_list = []

for chunk in pd.read_csv(file_path, chunksize=chunk_size, header = None):
    df_list.append(chunk)

df2 = pd.concat(df_list)

# %%
my_data_forPCA2 =df2

# %%
std_scaler = StandardScaler()
scaled_landDiff = std_scaler.fit_transform(my_data_forPCA2)
scaled_landDiff.shape


pca_texture = PCA(n_components=350)#era 14
b_texture = pca_texture.fit_transform(scaled_landDiff)
b_texture.shape #
